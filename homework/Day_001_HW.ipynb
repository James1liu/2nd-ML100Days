# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error

# %%
def mean_squared_error(y_test,y_pred):
    """
    請完成這個 Function 後往下執行
    """
    if(len(y_test) == len(y_pred)):
        TOTAL=0
        for num in range(0,len(y_pred)):  #
            TOTAL=TOTAL+(y_test[num]-y_pred[num]) ** 2 
        return TOTAL/(len(y_test)+1)
    else:
        return "ERROR"

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 224.129
# The Mean absolute error is 11.622

# %%
mean_absolute_error,沒有宣告
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-f787151af838> in <module>
# ----> 1 mean_absolute_error沒有宣告
#
# NameError: name 'mean_absolute_error沒有宣告' is not defined
